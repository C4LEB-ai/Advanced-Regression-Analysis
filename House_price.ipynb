# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
# %matplotlib inline
from sklearn.metrics import accuracy_score, f1_score
from category_encoders import TargetEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error


import random

seed = 42
random.seed(seed)
np.random.seed(seed)

import warnings
warnings.filterwarnings("ignore")

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
train_df.sample(15)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 892    893          20       RL         70.0     8414   Pave   NaN      Reg
# 1105  1106          60       RL         98.0    12256   Pave   NaN      IR1
# 413    414          30       RM         56.0     8960   Pave  Grvl      Reg
# 522    523          50       RM         50.0     5000   Pave   NaN      Reg
# 1036  1037          20       RL         89.0    12898   Pave   NaN      IR1
# 614    615         180       RM         21.0     1491   Pave   NaN      Reg
# 218    219          50       RL          NaN    15660   Pave   NaN      IR1
# 1160  1161         160       RL         24.0     2280   Pave   NaN      Reg
# 649    650         180       RM         21.0     1936   Pave   NaN      Reg
# 887    888          50       RL         59.0    16466   Pave   NaN      IR1
# 576    577          50       RL         52.0     6292   Pave   NaN      Reg
# ...

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train_df.shape, test_df.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
#concatenate the train and test data
data = pd.concat([train_df, test_df], axis = 0)
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
data.shape
# Out:
# (2919, 81)

# %%
data_temp = data.copy()
data_temp.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
data_temp.drop(('Id'), axis = 1, inplace = True)

# %%
data_temp.isna().sum()
# Out:
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
# Street              0
# Alley            2721
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         24
# MasVnrArea         23
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           81
# BsmtCond           82
# BsmtExposure       82
# BsmtFinType1       79
# BsmtFinSF1          1
# BsmtFinType2       80
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# CentralAir          0
# ...

# %%
data_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2915 non-null   object
#  2   LotFrontage    2433 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2917 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
# ...

# %% [markdown]
# # Analysis

# %%
# using a pandas function to check for numerical columns
def num_feat(data_temp):
    x = []
    for label, content in data_temp.items():
        if pd.api.types.is_numeric_dtype(content):
            x.append(label)
    return x
labels = num_feat(data_temp)

# %%
num_feat = data_temp[labels]
# Figure out the distribution of numerical features in the dataset features
num_feat.hist(figsize=(15, 20), bins=20,xlabelsize=8,\
                  ylabelsize=8)

plt.show()

# %%
#check for categorical features
for label, content in data_temp.items():
    if pd.api.types.is_string_dtype(content):
        print(label)
# Out:
# MSZoning
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive
# PoolQC
# Fence
# MiscFeature
# SaleType
# SaleCondition

# %%
# check for missing numerical columns
def cat_feat(data_temp):
    x =[]
    for label, content in data_temp.items():
        if pd.api.types.is_numeric_dtype(content):
            if pd.isnull(content).sum():
                x.append(label)
    return x
cat_feat = cat_feat(data_temp)

# %%
# Figure out the correlation among variables
count=1
plt.subplots(figsize=(25, 50))
for i in num_feat.columns:
    plt.subplot(10,4,count)
    sns.regplot(num_feat[i],num_feat['SalePrice'],\
               scatter_kws={'color':'navy'},\
               line_kws={'color': 'lightslategrey'})
    count+=1

plt.show()

# %% [markdown]
# #### comment
# - As demonstrated, The relationship between SalePrice and some features in our dataset appears with different degrees of strength.
# - However, looking at the graph alone will not tell us much about the correlation among the variables and between them and our target variable.

# %%
# Modifying the figure size
plt.figure(figsize=(30,25))
# Calculation of correlation among variables
corr_matrix = data_temp.corr()
# Masking the upper triangle for the heatmap since it shows the same values of correlation
mask_upp = np.triu(np.ones_like(corr_matrix, dtype=bool))

# plotting correlation heatmap
sns.heatmap(corr_matrix, cmap="YlGnBu",annot=True, fmt='.2f',\
            mask = mask_upp)
  
# displaying heatmap
plt.show()

# %% [markdown]
# comment
# - The above heatmap demonstrates the precise levels of correlation between the predictors and our target variable

# %%
data_temp.drop(["PoolQC","Fence","MiscFeature"], axis =1, inplace = True)

# %%
data_temp.fillna(0, inplace = True)

# %%
data_temp
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave     0      Reg
# 1             20       RL         80.0     9600   Pave     0      Reg
# 2             60       RL         68.0    11250   Pave     0      IR1
# 3             70       RL         60.0     9550   Pave     0      IR1
# 4             60       RL         84.0    14260   Pave     0      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1454         160       RM         21.0     1936   Pave     0      Reg
# 1455         160       RM         21.0     1894   Pave     0      Reg
# 1456          20       RL        160.0    20000   Pave     0      Reg
# 1457          85       RL         62.0    10441   Pave     0      Reg
# 1458          60       RL         74.0     9627   Pave     0      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
# data_temp= scale.transform(data_temp)
train= data_temp.iloc[:train_df.shape[0], :]
test= data_temp.iloc[train_df.shape[0]:, :-1]

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
train.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# ...

# %%
test.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# ...

# %%
X = train.drop(labels = ["SalePrice"], axis = 1)
y = train["SalePrice"]

# %%
categorical_features = labels

categorical_transformer = Pipeline(steps=[("imputer", SimpleImputer(strategy="most_frequent")),
                                          ("ohe", OneHotEncoder(handle_unknown="ignore"))])

# %%
numeric_features = cat_feat
numeric_transformer = Pipeline(steps=[ ("imputer", SimpleImputer(strategy="median")),
                                       ("scaler", StandardScaler())])

# %%
preprocessor = ColumnTransformer(transformers=[("num", numeric_transformer, numeric_features[:-1]), 
                                                 ("cat", categorical_transformer, categorical_features[:-1])])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
clf = Pipeline( 
    steps=[ ("preprocessor", preprocessor), 
           ("regressor", DecisionTreeRegressor())])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['LotFrontage', 'MasVnrArea',
#                                                    'BsmtFinSF1', 'BsmtFinSF2',
#                                                    'BsmtUnfSF', 'TotalBsmtSF',
#                                                    'BsmtFullBath',
#                                                    'BsmtHalfBath',
#                                                    'GarageYrBlt', 'GarageCars',
#                                                    'GarageArea']),
# ...

# %%
clf.score(X_train, y_train), clf.score(X_test, y_test)
# Out:
# (0.9999956251130148, 0.7988499850234398)

# %%
predictions = clf.predict(X_test)

# %%
mae = mean_absolute_error(y_test, predictions)
rmse = math.sqrt(mean_squared_error(y_test, predictions))
print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Mean Absolute Error: 28077.465753424658
# Root Mean Squared Error: 42869.98056085017

# %%
parameters = {
    "max_features": [0.7,0.8,0.9],
    "min_samples_split": [2,3,5,8,]
}

# %%
gridsearch = GridSearchCV(DecisionTreeRegressor(), param_grid=parameters,scoring="neg_root_mean_squared_error",
                          n_jobs=-1, verbose=1)

# %%
grid = Pipeline( 
    steps=[ ("preprocessor", preprocessor), 
           ("gridsearch", gridsearch)])

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['LotFrontage', 'MasVnrArea',
#                                                    'BsmtFinSF1', 'BsmtFinSF2',
#                                                    'BsmtUnfSF', 'TotalBsmtSF',
#                                                    'BsmtFullBath',
#                                                    'BsmtHalfBath',
#                                                    'GarageYrBlt', 'GarageCars',
# ...

# %%
print(grid.named_steps["gridsearch"].best_estimator_) 
print(grid.named_steps["gridsearch"].best_params_)
print(grid.named_steps["gridsearch"].best_score_)
# Out:
# DecisionTreeRegressor(max_features=0.7, min_samples_split=8)
# {'max_features': 0.7, 'min_samples_split': 8}
# -42638.844705691314

# %%
clf = Pipeline( 
    steps=[ ("preprocessor", preprocessor), 
           ("regressor", DecisionTreeRegressor(min_samples_split=8, max_features=0.8))])

# %%
clf.fit(X_train, y_train)
clf.score(X_train, y_train), clf.score(X_test, y_test)
# Out:
# (0.9681955817292078, 0.7766922351366445)

# %%
predicted = grid.predict(test)

# %%
submission_sample = pd.read_csv("sample_submission.csv")
submission_sample
# Out:
#         Id      SalePrice
# 0     1461  169277.052498
# 1     1462  187758.393989
# 2     1463  183583.683570
# 3     1464  179317.477511
# 4     1465  150730.079977
# ...    ...            ...
# 1454  2915  167081.220949
# 1455  2916  164788.778231
# 1456  2917  219222.423400
# 1457  2918  184924.279659
# 1458  2919  187741.866657
#
# [1459 rows x 2 columns]

# %%
# submission_sample.SalePrice = predicted
# submission_sample.to_csv("Submit_2.csv", index=False)

# %%
mae = mean_absolute_error(submission_sample.SalePrice, predicted)
rmse = math.sqrt(mean_squared_error(submission_sample.SalePrice, predicted))
print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Mean Absolute Error: 53104.78812222944
# Root Mean Squared Error: 70782.64929013552

# %% [markdown]
# # Model 2

# %%
clf3 = Pipeline( 
    steps=[ ("preprocessor", preprocessor), 
           ("regressor", ExtraTreesRegressor(min_samples_split= 8,max_features=0.8,
                                             n_estimators=150))])

# %%
clf3
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['LotFrontage', 'MasVnrArea',
#                                                    'BsmtFinSF1', 'BsmtFinSF2',
#                                                    'BsmtUnfSF', 'TotalBsmtSF',
#                                                    'BsmtFullBath',
#                                                    'BsmtHalfBath',
#                                                    'GarageYrBlt', 'GarageCars',
#                                                    'GarageArea']),
# ...

# %%
clf3.fit(X_train, y_train)
clf3.score(X_train, y_train), clf2.score(X_test, y_test)
# Out:
# (0.9891872091325686, 0.7508152478244137)

# %%
predictd = clf3.predict(test)

# %%
mae = mean_absolute_error(submission_sample.SalePrice, predictd)
rmse = math.sqrt(mean_squared_error(submission_sample.SalePrice, predictd))
print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Mean Absolute Error: 51853.048786763604
# Root Mean Squared Error: 68455.76892325326

# %%
submission_sample.SalePrice = predictd
submission_sample.to_csv("Submit_2.csv", index=False)
